# %%
import requests
import base64
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

# %%
URL = "https://api.spotify.com/"
auth = "https://accounts.spotify.com/api/token"
client_id = "13186e9c43c54bd9b02876922e205da6"
client_secret = "ad49eaa89c234431bb3a0b677d6b862c"
response_type = "token"
redirect_url = "https://localhost"

# %%
key = 'f0064908730c453cbed016cfa70e8c01'
endpoint = 'westus.api.cognitive.microsoft.com'
appId = '6646e66e-73b9-4fa3-a0cd-1a063818e3e7'
utterance = "I am feeling ill"

# %%
headers = {}

params = {
        'query': utterance,
        'timezoneOffset': '0',
        'verbose': 'true',
        'show-all-intents': 'true',
        'spellCheck': 'false',
        'staging': 'false',
        'subscription-key': key
}

# %%
r = requests.get(f'https://{endpoint}/luis/prediction/v3.0/apps/{appId}/slots/production/predict',headers=headers, params=params)

# %%
response_data = r.json()
intent = response_data['prediction']['topIntent']

# %%
client_credentials_manager = SpotifyClientCredentials(client_id=client_id, client_secret=client_secret)

# %%
sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager)

# %%
result = sp.recommendations(seed_genres={intent}) #search query

# %%
print(result)
# Out:
# {'tracks': [{'album': {'album_type': 'ALBUM', 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6Wr3hh341P84m3EI8qdn9O'}, 'href': 'https://api.spotify.com/v1/artists/6Wr3hh341P84m3EI8qdn9O', 'id': '6Wr3hh341P84m3EI8qdn9O', 'name': 'Rise Against', 'type': 'artist', 'uri': 'spotify:artist:6Wr3hh341P84m3EI8qdn9O'}], 'available_markets': ['AD', 'AE', 'AR', 'AT', 'AU', 'BE', 'BG', 'BH', 'BO', 'BR', 'CA', 'CH', 'CL', 'CO', 'CR', 'CY', 'CZ', 'DE', 'DK', 'DO', 'DZ', 'EC', 'EE', 'EG', 'ES', 'FI', 'FR', 'GB', 'GR', 'GT', 'HK', 'HN', 'HU', 'ID', 'IE', 'IL', 'IN', 'IS', 'IT', 'JO', 'JP', 'KW', 'LB', 'LI', 'LT', 'LU', 'LV', 'MA', 'MC', 'MT', 'MX', 'MY', 'NI', 'NL', 'NO', 'NZ', 'OM', 'PA', 'PE', 'PH', 'PL', 'PS', 'PT', 'PY', 'QA', 'RO', 'SA', 'SE', 'SG', 'SK', 'SV', 'TH', 'TN', 'TR', 'TW', 'US', 'UY', 'VN', 'ZA'], 'external_urls': {'spotify': 'https://open.spotify.com/album/4bnL97GIgtX6UCybyDzRMJ'}, 'href': 'https://api.spotify.com/v1/albums/4bnL97GIgtX6UCybyDzRMJ', 'id': '4bnL97GIgtX6UCybyDzRMJ', 'images': [{'height': 640, 'url': 'https://i.scdn.co/image/ab67616d0000b273cd97bdaa77ffd89f39b9e458', 'width': 640}, {'height': 300, 'url': 'https://i.scdn.co/image/ab67616d00001e02cd97bdaa77ffd89f39b9e458', 'width': 300}, {'height': 64, 'url': 'https://i.scdn.co/image/ab67616d00004851cd97bdaa77ffd89f39b9e458', 'width': 64}], 'name': 'The Sufferer & The Witness [International Version (Explicit)]', 'release_date': '2006-06-30', 'release_date_precision': 'day', 'total_tracks': 0, 'type': 'album', 'uri': 'spotify:album:4bnL97GIgtX6UCybyDzRMJ'}, 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6Wr3hh341P84m3EI8qdn9O'}, 'href': 'https://api.spotify.com/v1/artists/6Wr3hh341P84m3EI8qdn9O', 'id': '6Wr3hh341P84m3EI8qdn9O', 'name': 'Rise Against', 'type': 'artist', 'uri': 'spotify:artist:6Wr3hh341P84m3EI8qdn9O'}], 'available_markets': [], 'disc_number': 1, 'duration_ms': 195837, 'explicit': False, 'external_ids': {'isrc': 'USUM70603971'}, 'external_urls': {'spotify': 'https://open.spotify.com/track/58J1l73w3TcdpGqN0n1TiZ'}, 'href': 'https://api.spotify.com/v1/tracks/58J1l73w3TcdpGqN0n1TiZ', 'id': '58J1l73w3TcdpGqN0n1TiZ', 'is_local': False, 'name': 'Prayer Of The Refugee', 'popularity': 3, 'preview_url': None, 'track_number': 6, 'type': 'track', 'uri': 'spotify:track:58J1l73w3TcdpGqN0n1TiZ'}, {'album': {'album_type': 'ALBUM', 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3GzWhE2xadJiW8MqRKIVSK'}, 'href': 'https://api.spotify.com/v1/artists/3GzWhE2xadJiW8MqRKIVSK', 'id': '3GzWhE2xadJiW8MqRKIVSK', 'name': 'Underoath', 'type': 'artist', 'uri': 'spotify:artist:3GzWhE2xadJiW8MqRKIVSK'}], 'available_markets': ['AD', 'AE', 'AR', 'AT', 'AU', 'BE', 'BG', 'BH', 'BO', 'BR', 'CA', 'CH', 'CL', 'CO', 'CR', 'CY', 'CZ', 'DE', 'DK', 'DO', 'DZ', 'EC', 'EE', 'EG', 'ES', 'FI', 'FR', 'GB', 'GR', 'GT', 'HK', 'HN', 'HU', 'ID', 'IE', 'IL', 'IN', 'IS', 'IT', 'JO', 'JP', 'KW', 'LB', 'LI', 'LT', 'LU', 'LV', 'MA', 'MC', 'MT', 'MX', 'MY', 'NI', 'NL', 'NO', 'NZ', 'OM', 'PA', 'PE', 'PH', 'PL', 'PS', 'PT', 'PY', 'QA', 'RO', 'SA', 'SE', 'SG', 'SK', 'SV', 'TH', 'TN', 'TR', 'TW', 'US', 'UY', 'VN', 'ZA'], 'external_urls': {'spotify': 'https://open.spotify.com/album/6YQu7tXYfN1r2NLx8tfEI6'}, 'href': 'https://api.spotify.com/v1/albums/6YQu7tXYfN1r2NLx8tfEI6', 'id': '6YQu7tXYfN1r2NLx8tfEI6', 'images': [{'height': 640, 'url': 'https://i.scdn.co/image/ab67616d0000b27393f4522c1ccdd9599da61965', 'width': 640}, {'height': 300, 'url': 'https://i.scdn.co/image/ab67616d00001e0293f4522c1ccdd9599da61965', 'width': 300}, {'height': 64, 'url': 'https://i.scdn.co/image/ab67616d0000485193f4522c1ccdd9599da61965', 'width': 64}], 'name': 'Define The Great Line', 'release_date': '2006-01-01', 'release_date_precision': 'day', 'total_tracks': 0, 'type': 'album', 'uri': 'spotify:album:6YQu7tXYfN1r2NLx8tfEI6'}, 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3GzWhE2xadJiW8MqRKIVSK'}, 'href': 'https://api.spotify ...

# %%
print("artist: ", result['tracks'][0]['album']['artists'][0]['name'], 
      "\nalbum: ", result['tracks'][0]['album']['name'], 
      "\nid: ", result['tracks'][0]['album']['uri'])
# Out:
# artist:  Rise Against
# album:  The Sufferer & The Witness [International Version (Explicit)]
# id:  spotify:album:4bnL97GIgtX6UCybyDzRMJ

# %%
PARAMS = {'client_id': client_id, 'client_secret': client_secret, 'redirect_url': redirect_url}

# %%
BODY = {'grant_type':'client_credentials'}

# %%
PARAMS

# %%
r = requests.post(url = auth, headers={'Authorization': 'Basic MTMxODZlOWM0M2M1NGJkOWIwMjg3NjkyMmUyMDVkYTY6YWQ0OWVhYTg5YzIzNDQzMWJiM2EwYjY3N2Q2Yjg2MmM='}, params = BODY)

# %%
r.text
